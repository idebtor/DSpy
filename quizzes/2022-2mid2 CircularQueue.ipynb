# %% [markdown]
# 또 어려서부터 성경을 알았나니 성경은 능히 너로 하여금 그리스도 예수 안에 있는 믿음으로 말미암아 구원에 이르는 지혜가 있게 하느니라 모든 성경은 하나님의 감동으로 된 것으로 교훈과 책망과 바르게 함과 의로 교육하기에 유익하니 이는 하나님의 사람으로 온전하게 하며 모든 선한 일을 행할 능력을 갖추게 하려 함이라 (딤후3:15-17)
#
# -------
# <center><img src="https://github.com/idebtor/DSpy/blob/6b3676c3de29f85d2e7f30679676d1fd96d88b17/images/WelcomeToDataStructures.jpg?raw=true" width=1000></center>
#
# __NOTE:__ The following materials have been compiled and adapted from the numerous sources including my own. Please help me to keep this tutorial up-to-date by reporting any issues or questions. Send any comments or criticisms to `idebtor@gmail.com` Your assistances and comments will be appreciated.
#
# --------

# %% [markdown]
# <b style="font-size:30px">  Chapter 3. Linear Data Structures (선형 자료구조) </b>
#
# : 선형 자료구조란 무엇인가 (스택,큐,리스트 등)
#
# --------------

# %% [markdown]
# __무감독 양심 시험으로 실시합니다. Open Book 그리고 인터넷 검색이 가능합니다. 다른 사람들의 도움을 받는 것은 Cheating에 해당합니다. 한동의 학우들이 "정직하고 성실하게" 코딩할 수 있는 충분히 시간이 제공됩니다.__
# God is good all the time~
# (a debtor)<><
#
#
# __Honor Code:__  Your signature or name below represents your promise that this quiz is solely your own work.
#
# __Signature:__
#
#
# ------

# %% [markdown]
# # (4.0p) Problem - Circular Queue
#
# 다음은 `QueueCircular` 클래스 코드는 강의에서 소개된 간단한 (버그를 포함한) Code snippet입니다. 주어진 스텝에 따라 가면서 Sample Run을 가이드라인으로 참고하여 `QueueCircular`클래스를 완성하십시오.

# %%
class QueueCircular:
    def __init__(self, size):
        self.items = [None] * size
        self.MAX = size
        self.front = -1
        self.back = -1
        
    def enqueue(self, item): # if not full
        if (self.back + 1) % self.MAX == self.front:
            print("The circular queue is full.")
        elif self.front == -1:
            self.front = 0
            self.back = 0
            self.items[self.back] = item
        else:
            self.back = (self.back + 1) % self.MAX  
            self.items[self.back] = item

    def dequeue(self): # if not empty
        if self.front == -1:
            print("The circular queue is empty.")
        elif self.front == self.back:
            item = self.items[self.front]
            self.front = -1
            self.back = -1
            self.items[self.back] = item
        else:
            item = self.items[self.front]
            self.front = (self.front + 1) % self.MAX  
            return item

    def is_empty():
        return self.front == -1

# %% [markdown]
# ## Step 1
#
# 위에 주어진 `QueueCircular()` 클래스 코드에 존재하는 버그를 찾기 위하여 다양한 경우를 시험하여 보십시오.
# - 위 코드의 버그가 나타낼 수 있는 간단한 예제를 제시하십시오.
# - 위 코드의 버그를 수정한 코드를 아래 셀에 제시하고, 다시 테스트하십시오.
#
# __Place your test case to show the bug:__

# %%
# a simple test case to show here the bug in the code above
if __name__ == '__main__':  
    q = QueueCircular(4)           
    q.enqueue(12)  
    q.enqueue(17)  
    q.enqueue(25)  
    q.enqueue(11)  
    print('dequeue:', q.dequeue())
    print('dequeue:', q.dequeue()) 
    print('dequeue:', q.dequeue())
    print('dequeue:', q.dequeue())
# Out:
# dequeue: 12
# dequeue: 17
# dequeue: 25
# dequeue: None

# %% [markdown]
# __Place your code debugged and the simple case to test here:__

# %%
# your code debugged here

class QueueCircular:
    def __init__(self, size):
        self.items = [None] * size
        self.MAX = size
        self.front = -1
        self.back = -1
        
    def enqueue(self, item): # if not full
        if (self.back + 1) % self.MAX == self.front:
            print("The circular queue is full.")
        elif self.front == -1:
            self.front = 0
            self.back = 0
            self.items[self.back] = item
        else:
            self.back = (self.back + 1) % self.MAX  
            self.items[self.back] = item

    def dequeue(self): # if not empty
        if self.front == -1:
            print("The circular queue is empty.")
        elif self.front == self.back:
            item = self.items[self.front]
            self.front = -1
            self.back = -1
            self.items[self.back] = item
        else:
            item = self.items[self.front]
            self.front = (self.front + 1) % self.MAX  
            return item

    def is_empty():
        return self.front == -1
    
# a simple test case here to show the bug fixed in the code above
if __name__ == '__main__':
    None

# %% [markdown]
# ## Step 2
# - 코드 디버깅을 할 때, Queue의 `items`, `front`와 `back`을 출력을 해보면 도움이 됩니다. 이 세가지를 출력하는 `dumpout()` 메소드를 구현하십시오.
# - `is_full()` 메소드를 구현하십시오. 개발자가 이 메소드를 직접 사용하지 않을지라도, 클래스의 완성도를 높이며 외부 사용자가 사용할 수 있도록 하는 배려입니다.
# - Queue가 full일 때에는 더 이상 `enqueue()`를 할 수 없습니다. 만약 `enqueue()`를 시도한다면 에리 메시지를 출력해야 합니다.
# - 또한 Queue가 empty인데 `dequeue()`를 시도한다면, 에러 메시지를 출력해야 합니다. 이와 같은 두 가지의 경우가 발생하면, Sample Run과 같이 `front`와 `back`의 현재 값을 에러 메시지에 추가로 제시하십시오.

# %% [markdown]
# __Sample Run:__
# ```
# if __name__ == '__main__':
#     q = QueueCircular(4)
#     q.dumpout()
#     q.dequeue()
#     q.enqueue(12)
#     q.enqueue(17)
#     q.enqueue(25)
#     q.enqueue(11)
#     q.enqueue(30)
#     q.dumpout()
#     print('dequeue:', q.dequeue())
#     print('dequeue:', q.dequeue())
#     q.dumpout()
# ```

# %% [markdown]
# __Expected Output:__
# ```
# dump items: [None, None, None, None]
# dump front:back: [-1:-1]
# The circular queue is empty[-1:-1].
# The circular queue is full[0:3].
# dump items: [12, 17, 25, 11]
# dump front:back: [0:3]
# dequeue: 12
# dequeue: 17
# dump items: [12, 17, 25, 11]
# dump front:back: [2:3]
# ```
#
# __Use your code solution from Step 1:__

# %%
# use the bug fixed version here, and add the code to show the specs
class QueueCircular:
    def __init__(self, size):
        self.items = [None] * size
        self.MAX = size
        self.front = -1
        self.back = -1
        
    def enqueue(self, item): # if not full
        if (self.back + 1) % self.MAX == self.front:
            print("The circular queue is full.")
        elif self.front == -1:
            self.front = 0
            self.back = 0
            self.items[self.back] = item
        else:
            self.back = (self.back + 1) % self.MAX  
            self.items[self.back] = item

    def dequeue(self): # if not empty
        if self.front == -1:
            print("The circular queue is empty.")
        elif self.front == self.back:
            item = self.items[self.front]
            self.front = -1
            self.back = -1
            self.items[self.back] = item
        else:
            item = self.items[self.front]
            self.front = (self.front + 1) % self.MAX  
            return item
        
    def is_empty():
        return self.front == -1
        
    def is_full():
        pass
    
    def dumpout(self):
        pass

if __name__ == '__main__':
    q = QueueCircular(4)
    q.dumpout()
    q.dequeue()
    q.enqueue(12)  
    q.enqueue(17)  
    q.enqueue(25)  
    q.enqueue(11)  
    q.enqueue(30)
    q.dumpout()
    print('dequeue:', q.dequeue())
    print('dequeue:', q.dequeue()) 
    q.dumpout()
# Out:
# The circular queue is empty.
# The circular queue is full.
# dequeue: 12
# dequeue: 17

# %% [markdown]
# ## Step 3
# - 지금의 `dequeue()`를 실행하면 item을 반환되고, `front`을 조정합니다. `items[]`의 내용 자체는 변화가 없습니다.  코드를 디버깅할 때 도움이 될 수 있도록 `dequeue()`를 실행한 `items[]`의 item을 `None`으로 대체하십시오.
# - `size()` 메소드를 정의하십시오. 이 부분을 정확히 이해하면, Circluar Queue를 이해하고, 이를 구현하는데 도움이 됩니다.
#
# __Sample Run:__
# ```
# if __name__ == '__main__':
#     q = QueueCircular(4)
#     print('size:', q.size())
#     q.dumpout()
#     q.dequeue()
#     q.enqueue(12)
#     q.enqueue(17)
#     q.enqueue(25)
#     q.dequeue()
#     q.enqueue(11)
#     print('size:', q.size())
#     q.dumpout()
#     print('dequeue:', q.dequeue())
#     print('dequeue:', q.dequeue())
#     q.enqueue(55)
#     print('size:', q.size())
#     q.dumpout()
# ```

# %% [markdown]
# __Expected Output:__
# ```
# size: 0
# dump items: [None, None, None, None]
# dump front:back: [-1:-1]
# The circular queue is empty[-1:-1].
# size: 3
# dump items: [None, 17, 25, 11]
# dump front:back: [1:3]
# dequeue: 17
# dequeue: 25
# size: 2
# dump items: [55, None, None, 11]
# dump front:back: [3:0]
# ```

# %%
# use the bug fixed version here, and add the code to show the specs
class QueueCircular:
    def __init__(self, size):
        self.items = [None] * size
        self.MAX = size
        self.front = -1
        self.back = -1
        
    def enqueue(self, item): # if not full
        if (self.back + 1) % self.MAX == self.front:
            print("The circular queue is full.")
        elif self.front == -1:
            self.front = 0
            self.back = 0
            self.items[self.back] = item
        else:
            self.back = (self.back + 1) % self.MAX  
            self.items[self.back] = item

    def dequeue(self): # if not empty
        if self.front == -1:
            print("The circular queue is empty.")
        elif self.front == self.back:
            item = self.items[self.front]
            self.items[self.front] = None
            self.front = -1
            self.back = -1
            return item
        else:
            item = self.items[self.front]
            self.items[self.front] = None
            self.front = (self.front + 1) % self.MAX  
            return item
        
    def is_empty():
        return self.front == -1
        
    def is_full():
        pass
    
    def dumpout(self):
        pass
    
    def size(self):
        pass

if __name__ == '__main__':
    q = QueueCircular(4)
    print('size:', q.size())
    q.dumpout()
    q.dequeue()
    q.enqueue(12)  
    q.enqueue(17)  
    q.enqueue(25)  
    q.dequeue() 
    q.enqueue(11)
    print('size:', q.size())
    q.dumpout()
    print('dequeue:', q.dequeue())
    print('dequeue:', q.dequeue()) 
    q.enqueue(55)
    print('size:', q.size())
    q.dumpout()
# Out:
# size: 0
# dump items: [None, None, None, None]
# dump front:back: [-1:-1]
# The circular queue is empty[-1:-1].
# size: 3
# dump items: [None, 17, 25, 11]
# dump front:back: [1:3]
# dequeue: 17
# dequeue: 25
# size: 2
# dump items: [55, None, None, 11]
# dump front:back: [3:0]

# %% [markdown]
# ## Step 4
# - 출력을 위해 `__repr__()` 메소드를 재정의하십시오.
# - 출력할 때, 요소들은 쉼표(,)로 분리되어 있는 것에 유의하십시오. Extra 쉼표가 발생하지 않도록 하십시오. 예를 들면, 아래와 같이 출력이 되어야 합니다.
# ```
# QueueCircular([12, 17, 25, 11])
# ```

# %% [markdown]
# __Sample Run:__
# ```
# if __name__ == '__main__':
#     q = QueueCircular(7)
#     print(q)
#     for i in range(5, 10):
#         q.enqueue(i)
#     print(q)
#     q.dumpout()
#     q.dequeue()
#     q.dequeue()
#     q.dequeue()
#     print('size:', q.size())
#     print(q)
#     for i in range(4):
#         q.enqueue(i)
#     print('size:', q.size())
#     print(q)
#     q.dumpout()
# ```
# __Expected Output:__
# ```
# QueueCircular([])
# QueueCircular([5, 6, 7, 8, 9])
# dump items: [5, 6, 7, 8, 9, None, None]
# dump front:back: [0:4]
# size: 2
# QueueCircular([8, 9])
# size: 6
# QueueCircular([8, 9, 0, 1, 2, 3])
# dump items: [2, 3, None, 8, 9, 0, 1]
# dump front:back: [3:1]
# ```

# %%
#%%writefile queueCircular.py

# use the bug fixed version here, and add the code to show the specs
class QueueCircular:
    def __init__(self, size):
        self.items = [None] * size
        self.MAX = size
        self.front = -1
        self.back = -1
        
    def enqueue(self, item): # if not full
        if (self.back + 1) % self.MAX == self.front:
            print("The circular queue is full.")
        elif self.front == -1:
            self.front = 0
            self.back = 0
            self.items[self.back] = item
        else:
            self.back = (self.back + 1) % self.MAX  
            self.items[self.back] = item

    def dequeue(self): # if not empty
        if self.front == -1:
            print("The circular queue is empty.")
        elif self.front == self.back:
            item = self.items[self.front]
            self.items[self.front] = None
            self.front = -1
            self.back = -1
            return item
        else:
            item = self.items[self.front]
            self.items[self.front] = None
            self.front = (self.front + 1) % self.MAX  
            return item

    def is_empty():
        return self.front == -1

    def is_full():
        pass
    
    def dumpout(self):
        pass
    
    def size(self):
        pass

    def __repr__(self):
        pstr = 'QueueCircular(['
        if self.front == -1:
            return pstr + '])'
        # your code here
        return pstr + '])'
    
if __name__ == '__main__':
    q = QueueCircular(7)  
    print(q)
    for i in range(5, 10):
        q.enqueue(i)  
    print(q)
    q.dumpout()
    q.dequeue()  
    q.dequeue() 
    q.dequeue()
    print('size:', q.size())
    print(q)
    for i in range(4):
        q.enqueue(i)  
    print('size:', q.size())
    print(q)
    q.dumpout()
# Out:
# QueueCircular([])
# QueueCircular([5, 6, 7, 8, 9])
# dump items: [5, 6, 7, 8, 9, None, None]
# dump front:back: [0:4]
# size: 2
# QueueCircular([8, 9])
# size: 6
# QueueCircular([8, 9, 0, 1, 2, 3])
# dump items: [2, 3, None, 8, 9, 0, 1]
# dump front:back: [3:1]

# %% [markdown]
# # (Optional Bonus: 2.0 ~ 5.0p) Problem 2
#
# 이 보너스 문제는 상대평가와 절대평가를 병행합니다. 절대 평가로 아래 명시된 구현 조건을 다 만족하면 2점이 주어지고, 또한 상대적으로 가장 잘 구현한 코드와 정리(문서)에는 1~3점까지 주어집니다. 지금까지 공부해온 것처럼, 코딩을 잘할 뿐만 아니라 독자들이 잘 이해하며 Presentation(or Documentation)하는 것이 중요합니다.
#
# __Dynamically Resizable Circular Queue__
#
# - 큐의 요소를 저장하는 items의 크기를 Successive Doubling 알고리즘으로 구현하는 클래스는 __QueueCircularDy__, 반면에 일정한 크기로 items를 증가하는 클래스는 __QueueCircularRe__ 로 각각 이름하여 구현합니다.
#
# - Successive Doubling은 Queue size가 full인 상태(size == capacity)에서 enqueue 요청이 있을 경우, Queue capacity를 두 배로 확장합니다. 또한 dequeue를 실행한 직후, Queue size를 점검하여 capacity의 quarter full(1/4)이면, Queue capacity를 half(1/2)로 줄입니다.
# - Fixed size로 capacity를 조정할 때는 일정한 크기 즉 10, 100 혹은 1,000씩 늘리거나 줄입니다.
#
# - 각각의 클래스의 Time Complexity 테스트하는 코드를 작성하십시오.
#     - 테스트할 때는 각각의 클래스의 queue 요소들이 증가할 때와 감소할 때, capacity와 size의 변화를 관찰할 수 있어야 합니다.
#     - Queue items의 빈 곳은 None으로 채워둡니다.
#
# - 각각의 클래스에 대해 Empirical Time analysis를 진행하여 O(n) 혹은 O(n^2)인지를 숫자적으로 계산하고, 또한 그래프로 나타내십시오.

# %% [markdown]
# # Reference
# - Circular Queue Data Structure, [Here](https://www.programiz.com/dsa/circular-queue)

# %% [markdown]
# ------
# 또 어려서부터 성경을 알았나니 성경은 능히 너로 하여금 그리스도 예수 안에 있는 믿음으로 말미암아 구원에 이르는 지혜가 있게 하느니라 모든 성경은 하나님의 감동으로 된 것으로 교훈과 책망과 바르게 함과 의로 교육하기에 유익하니 이는 하나님의 사람으로 온전하게 하며 모든 선한 일을 행할 능력을 갖추게 하려 함이라 (딤후3:15-17)
