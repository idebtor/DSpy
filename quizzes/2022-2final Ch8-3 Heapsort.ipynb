# %% [markdown]
# 여호와는 나의 목자시니 내게 부족함이 없으리로다 그가 나를 푸른 풀밭에 누이시며 쉴 만한 물 가로 인도하시는도다 내 영혼을 소생시키시고 자기 이름을 위하여 의의 길로 인도하시는도다 내가 사망의 음침한 골짜기로 다닐지라도 해를 두려워하지 않을 것은 주께서 나와 함께 하심이라 주의 지팡이와 막대기가 나를 안위하시나이다 주께서 내 원수의 목전에서 내게 상을 차려 주시고 기름을 내 머리에 부으셨으니 내 잔이 넘치나이다 내 평생에 선하심과 인자하심이 반드시 나를 따르리니 내가 여호와의 집에 영원히 살리로다 (시23:1-6)
#
# -------
# <center><img src="https://github.com/idebtor/DSpy/blob/6b3676c3de29f85d2e7f30679676d1fd96d88b17/images/WelcomeToDataStructures.jpg?raw=true" width=1000></center>
#
# __NOTE:__ The following materials have been compiled and adapted from the numerous sources including my own. Please help me to keep this tutorial up-to-date by reporting any issues or questions. Send any comments or criticisms to `idebtor@gmail.com` Your assistances and comments will be appreciated.
#
# --------

# %% [markdown]
# <b style="font-size:30px">  Chapter 8. Heapsort Implementation</b>
#
# Min-heap과 Max-heap을 하나의 코드 안에서 자유롭게 바꿀 수 있는 Heap코드를 완성하고, 또한 Heapsort를 구현하는 문제입니다.
#
# - Step 1: Conversion between Min-heap and Max-heap
# - Step 2: Heapsort
#
# 앞 단원에서 배운 Heap and Priority Queue에 대해 다음과 같은 관찰을 하였습니다.

# %% [markdown]
# __Review: Observations from Heap and Priority Queue Lecture__
#
# __관찰 1:__ 힙을 생성하는 과정 즉 BuildHeap()이 $ O(n) $로 이루어진다는 것이 이해되지 않을 수 있습니다. 이를 증명하는 것은 복잡하여 더 깊은 공부가 필요합니다. 우선 리스트에서 힙을 생성하는 것이 $ O(n) $의 시간으로 된다고 했을 때, 힙을 사용한 정렬 알고리즘이 $ O(n \log n) $을 갖도록 만들 수 있을 것입니다.
#
# __관찰 2:__ 힙의 요소를 root부터 하나씩 제거하면서, 그 결과를 리스트에 저장해서 출력하면 정렬된 결과가 도출이 됩니다. 힙의 각 요소를 삭제하지 않고, 정렬된 결과를 얻으려면 어떻게 하면 되는지는 연습문제로 해볼 수 있습니다.
#
# __관찰 3:__ 힙의 노드는 파이썬의 리스트에 저장하고 관리됩니다. insert할 때 리스트의 마지막에 추가(append)하고, 삭제할 때에도 마지막 요소를 삭제합니다. 리스트의 root를 계속해서 삭제할 때, 이들을 차례대로 리스트의 끝에 저장하면, 이 요소들을 인하여 sorted list를 얻을 수 있습니다. 이를 연습 문제에서 시도합니다.
#
# __관찰 4:__ 요소들을 heap 데이터 구조 안에서 이동할 때마다 비교 연산이 일어납니다. 이 비교에 따라서 힙의 종류 즉 min-heap과 max-heap이 결정이 됩니다. 위의 코드는 min-heap을 구현한 것이며, 의도적으로 비교가 필요할 때마다 more()함수를 사용하였습니다. 이를 less()함수로 교체하면 위의 코드는 max-heap으로 작동합니다. 이를 연습 문제에서 시도합니다.

# %% [markdown]
# # Conversion between Min-heap and Max-heap
#
# - 먼저 아래 코드 셀에 있는 BinHeap 클래스를 완성하고 확인하십시오.
#     - `less(), more(), swap()` 메소드를 추가하십시오.
#     - `heapify()`를 추가하십시오.
#     - `minChild()` 메소드를 사용하지 마십시오.
#
# - 그 다음, 강의에서 배운대로, min-heap과 max-heap 자유롭게 전환하는데 필요한 코드를 추가하거나 수정하십시오.
#     - `__init__()` 메소드의 인자로 `min`을 추가하십시오.
#
# - 아래 주어진 코드에는 비효율적인 코드 즉 불필요한 연산을 하는 코드를 수정하고, __ANSWER:__ 부분에 그 이유를 설명하십시오.

# %% [markdown]
# __ANSWER:__
# .
# .
# .
# .
# .

# %% [markdown]
# __Sample Run:__
# ```
# if __name__ == '__main__':
#     my = BinHeap(False)                            # begin with max-heap
#     my.buildHeap([17, 15, 16, 12, 13, 99])
#     print('N:', my.N)
#     print('len:', len(my.heap))
#     print('max-heap:', my.heap)
#     my.draw()
#
#     print('insert 1 & 100')
#     my.insert(1)
#     my.insert(100)
#     my.draw()
#
#     print('convert max to min-heap')
#     my.heapify(True)
#     my.draw()
# ```

# %% [markdown]
# __Expected Output:__
# ```
# N: 6
# len: 7
# max-heap: [0, 99, 15, 17, 12, 13, 16]
#       99
#       / \
#      /   \
#     /     \
#    15     17
#   / \     /
#  /   \   16
# 12   13
# insert 1 & 100
#         100
#         / \
#        /   \
#       /     \
#      99     17
#     / \     / \
#    /   \   16  1
#   15   13
#  /
# 12
# convert max to min-heap
#            1
#           / \
#          /   \
#         /     \
#        /       \
#       /         \
#      12         16
#     / \         / \
#    /   \       /   \
#   15   13    100   17
#  /
# 99
# ```

# %%
#%load binheap.py
from dspy.drawtree import draw_level_order 

class BinHeap:
    def __init__(self):                       # set more for min-heap, less for max-heap 
        self.heap = [0]                       # list, index 0 is not used
        self.N = 0                            # points the last valid heap element index
        self.comp = None                      # comparator to switch between min-heap & max-heap
        
    def swap(self, p, k):                     # swap two elements
        self.heap[p], self.heap[k] = self.heap[k], self.heap[p]

    def swim(self,i):                         # append key and swim up
        while i // 2 > 0:
            if self.heap[i] < self.heap[i // 2]:
                self.swap(i, i//2) 
            i = i // 2

    def insert(self, key):                     # check N and len(heap) before using
        self.heap.append(key)                  # append() or list index  
        self.N += 1  
        self.swim(self.N)

    def sink(self,i):                          # try this without using minChild()
        while (i * 2) <= self.N:               # code is shown above
            mc = self.minChild(i)
            if self.heap[i] > self.heap[mc]:
                self.swap(i, mc) 
            i = mc

    def minChild(self,i):                      # used in sink, but try not to use this
        if i * 2 + 1 > self.N:
            return i * 2
        else:
            if self.heap[i*2] < self.heap[i*2+1]:
                return i * 2
            else:
                return i * 2 + 1
    
    def delete(self):
        retval = self.heap[1]                  # root is saved to return
        self.heap[1] = self.heap[self.N]       # last element becomes root - need sink it
        self.N -= 1                            # reduce size by one
        self.heap.pop()                        # remove the last element (it will be unnecessary)
        self.sink(1)                           # now, sink down the root to make it heap-ordered
        return retval
            
    def buildHeap(self, arr):                  # build heap from input arr list
        self.heap = [0] + arr[:]               # copy arr and set the initial heap
        self.N = len(arr)                      # set the size
        i = len(arr)                           # get the last internal node
        while i > 0:                           # sink from the last internal node to root 1
            self.sink(i)                       # O(n) time complexity
            i -= 1
  
    def heapify(self):                         # build heap from existing self.heap
        self.buildHeap(self.heap[1:])
    
    def __str__(self):
        return str(list(self.heap[1:]))
    
    def draw(self):                            # this works for numbers only
        draw_level_order(str(self.heap[1:]))
            
if __name__ == '__main__':
    my = BinHeap()
    my.buildHeap([9, 5, 6, 2, 3])
    print('number of elements N:', my.N)
    print('  lengh of heap list:', len(my.heap))
    print('    heap list stored:', my.heap)
    my.draw()
    
    print('\ninserting: 7 - already heap-ordered')
    my.insert(7)
    my.draw()
    print('\ninserting: 1 - swim up, become root')
    my.insert(1)
    my.draw()
    
    print('\ndeleting root to sort - heap depleted')
    my_sorted = [ my.delete() for x in range(my.N) ]
    print('my_sorted:', my_sorted)
    print('number of elements N:', my.N)
    print('  lengh of heap list:', len(my.heap))
    print('    heap list stored:', my.heap)

# %% [markdown]
# # Heapsort 구현

# %% [markdown]
# 지금까지 배운 힙을 사용하여 Heapsort 알고리즘을 구현하십시오.
#
# Heapsort는 추가 공간이 필요하지 않는 제자리(in-place) 정렬 알고리즘으로서, 하나의 리스트를 이진 트리와 같이 다루게 됩니다. 이를 위하여
# - 위에 있는 코드 셀에서 테스트 코드 부분을 제외하고 모든 코드를 복사하여 아래 코드 셀에 붙이십시오.
# - `insert()` 메소드에서 `append()`를 사용할 때와 사용하지 않을 때를 구별하도록 코드를 수정하십시오.
# - `delete()` 메소드에서 `pop()`을 사용하지 않고, 트리의 끝부분(N+1)에 저장하도록 코드를 수정하십시오.

# %% [markdown]
# __Sample Run:__
# ```
# if __name__ == '__main__':
#     ur = BinHeap()
#     ur.buildHeap([9, 5, 6, 2, 3])
#     print('number of elements N:', ur.N)
#     print('  lengh of heap list:', len(ur.heap))
#     print('    heap list stored:', ur.heap)
#     ur.draw()
#
#     print('\ninserting: 7 - already heap-ordered')
#     ur.insert(7)
#     ur.draw()
#     print('\ninserting: 1 - swim up, become root')
#     ur.insert(1)
#     ur.draw()
#
#     print('\ndeleting root to sort - heap depleted')
#     ur_sorted = [ ur.delete() for x in range(ur.N) ]
#     print('ur_sorted:', ur_sorted)
#     print('number of elements N:', ur.N)
#     print('  lengh of heap list:', len(ur.heap))
#     print('    heap list stored:', ur.heap)
#
#     print('\nrecover the original tree back')
#     ur.heapify(True)
#     ur.draw()
# ```

# %% [markdown]
# __Expected Output:__
# ```
# number of elements N: 5
#   lengh of heap list: 6
#     heap list stored: [0, 2, 3, 6, 5, 9]
#     2
#    / \
#   3   6
#  / \
# 5   9
#
# inserting: 7 - already heap-ordered
#       2
#      / \
#     /   \
#    /     \
#   3       6
#  / \     /
# 5   9   7
#
# inserting: 1 - swim up, become root
#       1
#      / \
#     /   \
#    /     \
#   3       2
#  / \     / \
# 5   9   7   6
#
# deleting root to sort - heap depleted
# ur_sorted: [1, 2, 3, 5, 6, 7, 9]
# number of elements N: 0
#   lengh of heap list: 8
#     heap list stored: [0, 9, 7, 6, 5, 3, 2, 1]
#
# recover the original tree back
#       1
#      / \
#     /   \
#    /     \
#   3       2
#  / \     / \
# 5   7   9   6
# ```

# %%
if __name__ == '__main__':
    ur = BinHeap()
    ur.buildHeap([9, 5, 6, 2, 3])
    print('number of elements N:', ur.N)
    print('  lengh of heap list:', len(ur.heap))
    print('    heap list stored:', ur.heap)
    ur.draw()
    
    print('\ninserting: 7 - already heap-ordered')
    ur.insert(7)
    ur.draw()
    print('\ninserting: 1 - swim up, become root')
    ur.insert(1)
    ur.draw()
    
    print('\ndeleting root to sort - heap depleted')
    ur_sorted = [ ur.delete() for x in range(ur.N) ]
    print('ur_sorted:', ur_sorted)
    print('number of elements N:', ur.N)
    print('  lengh of heap list:', len(ur.heap))
    print('    heap list stored:', ur.heap)
    
    print('\nrecover the original tree back')
    ur.heapify(True)
    ur.draw()

# %% [markdown]
# ------
#
# <b style="font-size:20px">  Happy Coding! </b>
# <b style="font-size:30px">  God is good all the time~ </b>
#
# ------

# %% [markdown]
# ------
# 여호와는 나의 목자시니 내게 부족함이 없으리로다 그가 나를 푸른 풀밭에 누이시며 쉴 만한 물 가로 인도하시는도다 내 영혼을 소생시키시고 자기 이름을 위하여 의의 길로 인도하시는도다 내가 사망의 음침한 골짜기로 다닐지라도 해를 두려워하지 않을 것은 주께서 나와 함께 하심이라 주의 지팡이와 막대기가 나를 안위하시나이다 주께서 내 원수의 목전에서 내게 상을 차려 주시고 기름을 내 머리에 부으셨으니 내 잔이 넘치나이다 내 평생에 선하심과 인자하심이 반드시 나를 따르리니 내가 여호와의 집에 영원히 살리로다 (시23:1-6)
